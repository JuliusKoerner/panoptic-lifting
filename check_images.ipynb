# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob

# %%
#basepath = '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0'
#basepath = '/home/rozenberszki/project/panoptic-lifting/runs/room_0_test_01171740_PanopLi_replicaroom0_easy-longshoreman'

# %%
#semantics = glob.glob(basepath + '/rs_semantics/*')

# %%
semantics
# Out:
# ['/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0160.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0729.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0297.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0255.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0466.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0275.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0665.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0359.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0261.png',
#  '/home/rozenberszki/project/panoptic-lifting/data/replica/room_0/rs_semantics/0_0450.png',
# ...

# %%
import cv2
#cv2.imread('/home/rozenberszki/D_Project/wsnsl/Datasets/data/fe1733741f/iphone/depth/frame_000210.png', cv2.IMREAD_UNCHANGED)
plt.hist(np.array(cv2.imread('/home/rozenberszki/D_Project/wsnsl/Datasets/data/fe1733741f/iphone/depth/frame_000210.png', cv2.IMREAD_UNCHANGED)).flatten(), bins=100)
plt.show()

# %%
import seaborn as sns
sns.heatmap(plt.imread('/home/rozenberszki/D_Project/wsnsl/Datasets/data/fe1733741f/iphone/depth/frame_000210.png')/1000)
# Out:
# <AxesSubplot:>

# %%
indices = range(20)

# %%
np.array(plt.imread(semantics[0]))
# Out:
# array([[0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        ...,
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 7.629511e-05,
#         7.629511e-05, 7.629511e-05],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 7.629511e-05,
#         7.629511e-05, 7.629511e-05],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, ..., 7.629511e-05,
#         7.629511e-05, 7.629511e-05]], dtype=float32)

# %%
plt.imshow(plt.imread('/home/rozenberszki/project/gen_replica/room0_0_6/semantic_instance/semantic_instance_0.png'))

# %%
for idx in indices:
    plt.imshow(plt.imread(semantics[idx]))
    plt.show()
    plt.close()
